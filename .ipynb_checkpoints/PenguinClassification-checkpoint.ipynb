# %% [markdown]
# # Classification of Antarctic Penguin Species

# %% [markdown]
# This project aims to train a decision tree classifier on a data set of three antarctic pengiun species. The three species are the Adélie penguins, the Gentoo penguins and Chinstrap penguins.
#
#
#
#
# The data was collected and made available by Dr. Kristen Gorman and the Palmer Station, Antarctica LTER, a member of the Long Term Ecological Research Network.
#
# Gorman KB, Williams TD, Fraser WR (2014) Ecological Sexual Dimorphism and Environmental Variability within a Community of Antarctic Penguins (Genus Pygoscelis). PLoS ONE 9(3): e90081. doi:10.1371/journal.pone.0090081

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv('penguins_lter.csv')

# %%
raw_data.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %% [markdown]
# ## Exploration of features of interest

# %%
data = raw_data[['Species', 'Region', 'Island', 'Culmen Length (mm)',
       'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex']]

# %%
#clean data with nan values
data = data.dropna()

# %%
#Only keep the datapoints with known sex and create new column combining species and sex
data_sex_known = data[(data['Sex'] == 'FEMALE') | (data['Sex'] == 'MALE')]
data_sex_known['Species_Sex'] = data_sex_known['Species'].str[:3] + '. ' + data_sex_known['Sex'].str[0]
# Out:
# C:\Users\gmoha\AppData\Local\Temp/ipykernel_13864/4122378646.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sex_known['Species_Sex'] = data_sex_known['Species'].str[:3] + '. ' + data_sex_known['Sex'].str[0]

# %% [markdown]
# ### First we visualize the pair wise relationship and individual distributions of the penguin species.
#
# We immediately recognize that the Gentoo species is easily identifiable based on the culmen depth, flipper length and body mass. The culmen length, on the other hand, is essential to distinguish between the Adelie and the Chinstrap species.

# %%
g = sns.pairplot(data_sex_known, hue = 'Species')
g.fig.suptitle("Penguin Size Distribution by Species", y=1.08, size = 16, ha = 'right')

# %% [markdown]
# ### We repeat the visualization while further dividing the species by sex

# %%
g = sns.pairplot(data_sex_known, hue = 'Species_Sex')
g.fig.suptitle("Penguin Size Distribution by Species and Sex", y=1.08, size = 16)
# Out:
# Text(0.5, 1.08, 'Penguin Size Distribution by Species and Sex')

# %% [markdown]
# ### And lastly, the visualization of the features by sex

# %%
g = sns.pairplot(data_sex_known, hue = 'Sex', palette = {"MALE": 'royalblue', "FEMALE":'lightpink'})
g.fig.suptitle("Penguin Size Distribution by Sex", y=1.08, size = 16)
# Out:
# Text(0.5, 1.08, 'Penguin Size Distribution by Sex')

# %% [markdown]
# ## Classification

# %%
import sklearn.tree as tree
from sklearn.model_selection import train_test_split

# %%
X, y = data_sex_known[['Culmen Length (mm)','Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)']], data_sex_known['Species']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)
clf = tree.DecisionTreeClassifier(random_state=0)
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
accuracy = sum(y_predict == y_test)/len(y_test)
print("The Decision Tree Species Prediction Accuracy is {:.3f}".format(accuracy))
print("At a tree depth of {}".format(clf.tree_.max_depth))
tree.plot_tree(clf, max_depth = 1, fontsize = 8, feature_names = X.columns)
# Out:
# The Decision Tree Species Prediction Accuracy is 0.976
# At a tree depth of 6
# [Text(167.4, 181.2, 'Flipper Length (mm) <= 207.5\ngini = 0.645\nsamples = 249\nvalue = [104, 54, 91]'),
#  Text(83.7, 108.72, 'Culmen Length (mm) <= 44.65\ngini = 0.449\nsamples = 153\nvalue = [102, 50, 1]'),
#  Text(41.85, 36.23999999999998, '\n  (...)  \n'),
#  Text(125.55000000000001, 36.23999999999998, '\n  (...)  \n'),
#  Text(251.10000000000002, 108.72, 'Culmen Depth (mm) <= 17.65\ngini = 0.119\nsamples = 96\nvalue = [2, 4, 90]'),
#  Text(209.25, 36.23999999999998, '\n  (...)  \n'),
#  Text(292.95, 36.23999999999998, '\n  (...)  \n')]

# %%
X, y = data_sex_known[['Culmen Length (mm)','Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)']], data_sex_known['Sex']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)
clf =tree.DecisionTreeClassifier(criterion = 'entropy', random_state=0)
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
accuracy = sum(y_predict == y_test)/len(y_test)
print("Decision Tree Sex Prediction Accuracy: {:.3f}".format(accuracy))
print("At a tree depth of {}".format(clf.tree_.max_depth))
tree.plot_tree(clf, max_depth = 1, fontsize = 8, feature_names = X.columns)
# Out:
# Decision Tree Sex Prediction Accuracy: 0.905
# At a tree depth of 10
# [Text(167.4, 181.2, 'Culmen Depth (mm) <= 14.85\nentropy = 0.996\nsamples = 249\nvalue = [115, 134]'),
#  Text(83.7, 108.72, 'Body Mass (g) <= 5250.0\nentropy = 0.359\nsamples = 44\nvalue = [41, 3]'),
#  Text(41.85, 36.23999999999998, '\n  (...)  \n'),
#  Text(125.55000000000001, 36.23999999999998, '\n  (...)  \n'),
#  Text(251.10000000000002, 108.72, 'Body Mass (g) <= 3712.5\nentropy = 0.943\nsamples = 205\nvalue = [74, 131]'),
#  Text(209.25, 36.23999999999998, '\n  (...)  \n'),
#  Text(292.95, 36.23999999999998, '\n  (...)  \n')]

# %%
X, y = data_sex_known[['Culmen Length (mm)','Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)']], data_sex_known['Species_Sex']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)
clf = tree.DecisionTreeClassifier(criterion = 'entropy',  splitter='random', random_state=0)
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
accuracy = sum(y_predict == y_test)/len(y_test)
print("Decision Tree Species AND Sex Prediction Accuracy: {:.3f}".format(accuracy))
print("At a tree depth of {}".format(clf.tree_.max_depth))
tree.plot_tree(clf, max_depth = 1, fontsize = 8, feature_names = X.columns)
# Out:
# Decision Tree Species AND Sex Prediction Accuracy: 0.893
# At a tree depth of 13
# [Text(167.4, 181.2, 'Culmen Length (mm) <= 41.568\nentropy = 2.526\nsamples = 249\nvalue = [45, 59, 23, 31, 47, 44]'),
#  Text(83.7, 108.72, 'Culmen Length (mm) <= 39.614\nentropy = 1.077\nsamples = 90\nvalue = [44, 45, 0, 0, 1, 0]'),
#  Text(41.85, 36.23999999999998, '\n  (...)  \n'),
#  Text(125.55000000000001, 36.23999999999998, '\n  (...)  \n'),
#  Text(251.10000000000002, 108.72, 'Culmen Depth (mm) <= 14.081\nentropy = 2.249\nsamples = 159\nvalue = [1, 14, 23, 31, 46, 44]'),
#  Text(209.25, 36.23999999999998, '\n  (...)  \n'),
#  Text(292.95, 36.23999999999998, '\n  (...)  \n')]
